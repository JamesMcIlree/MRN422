# %%
import numpy as np
import matplotlib.pyplot as plt
f = open("SIG1709.txt","r")
frequencies1 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies1 = np.append(frequencies1,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude1 = np.sqrt(real**2 + imag**2)
plt.figure(1)
plt.plot(frequencies1, amplitude1)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Experiment Control Accelerometer 1")
plt.show() 

f = open("SIG1710.txt","r")
frequencies2 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies2 = np.append(frequencies2,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude2 = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies2, amplitude2)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Experiment Control Accelerometer 2")
plt.show() 

f = open("SIG1711.txt","r")
frequencies3 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies3 = np.append(frequencies3,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude3 = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies3, amplitude3)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Experiment Control Accelerometer 3")
plt.show() 

f = open("SIG1712.txt","r")
frequencies4 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies4 = np.append(frequencies4,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude4 = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies4, amplitude4)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Experiment Control Accelerometer 4")
plt.show() 

f = open("SIG1713.txt","r")
frequencies5 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies5 = np.append(frequencies5,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude5 = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies5, amplitude5)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Experiment Control Accelerometer 5")
plt.show() 

bar1 = {"Accel 1":max(amplitude1),"Accel 2":max(amplitude2),"Accel 3":max(amplitude3),"Accel 4":max(amplitude4),"Accel 5":max(amplitude5)} 
plt.figure(3)
plt.bar(bar1.keys(),bar1.values(), width = 0.6, color ='maroon')
plt.xlabel("Accelerometer Positions")
plt.ylabel("Average Highest Amplitude")
plt.title("Sheet 2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
f = open("SIG1734.txt","r")
frequencies1 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies1 = np.append(frequencies1,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude1 = np.sqrt(real**2 + imag**2)
plt.figure(1)
plt.plot(frequencies1, amplitude1)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Crack Experiment Accelerometer 1")
plt.show() 

f = open("SIG1735.txt","r")
frequencies2 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies2 = np.append(frequencies2,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude2 = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies2, amplitude2)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Crack Experiment Accelerometer 2")
plt.show() 

f = open("SIG1736.txt","r")
frequencies3 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies3 = np.append(frequencies3,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude3 = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies3, amplitude3)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Crack Experiment Accelerometer 3")
plt.show() 

f = open("SIG1737.txt","r")
frequencies4 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies4 = np.append(frequencies4,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude4 = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies4, amplitude4)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Crack Experiment Accelerometer 4")
plt.show() 

f = open("SIG1738.txt","r")
frequencies5 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies5 = np.append(frequencies5,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude5 = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies5, amplitude5)
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Crack Experiment Accelerometer 5")
plt.show()

bar1 = {"Accel 1":max(amplitude1),"Accel 2":max(amplitude2),"Accel 3":max(amplitude3),"Accel 4":max(amplitude4),"Accel 5":max(amplitude5)} 
plt.figure(3)
plt.bar(bar1.keys(),bar1.values(), width = 0.6, color ='maroon')
plt.xlabel("Accelerometer Positions")
plt.ylabel("Average Highest Amplitude")
plt.title("Position 1")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
f = open("SIG1715.txt","r")
frequencies = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies = np.append(frequencies,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies, amplitude)
plt.xlim(0,1000)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Experiment Accelerometer 3")
plt.show() 

count = 2
while count < amplitude.shape[0] - 2:
    if amplitude[count] > amplitude[count - 2] + 0.5 and amplitude[count] > amplitude[count + 2] + 0.5 and frequencies[count] <= 1000:
        print(frequencies[count],"is a natural frequency")
    count = count + 1
# Out:
# <img src="data:image/png;base64,..." width="640">
# 20.0 is a natural frequency
# 22.5 is a natural frequency
# 165.0 is a natural frequency
# 240.0 is a natural frequency
# 242.5 is a natural frequency
# 285.0 is a natural frequency
# 417.5 is a natural frequency
# 420.0 is a natural frequency
# 700.0 is a natural frequency
# 730.0 is a natural frequency
# 732.5 is a natural frequency
# 915.0 is a natural frequency
# 975.0 is a natural frequency
# 977.5 is a natural frequency

# %%
import numpy as np
import matplotlib.pyplot as plt

f = open("SIG1716.txt","r")
frequencies = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies = np.append(frequencies,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies, amplitude)
plt.xlim(0,1000)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Experiment Accelerometer 3")
plt.show() 

f = open("SIG1714.txt","r")
frequencies = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies = np.append(frequencies,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude = np.sqrt(real**2 + imag**2)
plt.figure(1)
plt.plot(frequencies, amplitude)
plt.xlim(0,1000)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Expreiment Accelerometer 1")
plt.show()

# %%
f = open("SIG1704.txt","r")
frequencies3 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies3 = np.append(frequencies3,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude3 = np.sqrt(real**2 + imag**2)
plt.figure(2)
plt.plot(frequencies3, amplitude3/max(amplitude3), label = "Experiment")
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.title("Experiment and Simulation Control Accelerometer 1")

f = open("graph_set1_DISP_ALL.out","r")
lines = np.array([])
for line in f:
    lines = np.append(lines, line)

f.close()
lines = lines[9::]
frequencies = np.array([])
amplitudes1 = np.array([])
amplitudes2 = np.array([])
amplitudes3 = np.array([])
amplitudes4 = np.array([])
amplitudes5 = np.array([])
for line in lines:
    split = line.split(";")
    frequencies = np.append(frequencies,float(split[0].strip()))
    amplitudes1 = np.append(amplitudes1,float(split[1].strip()))
    amplitudes2 = np.append(amplitudes2,float(split[2].strip()))
    amplitudes3 = np.append(amplitudes3,float(split[3].strip()))
    amplitudes4 = np.append(amplitudes4,float(split[4].strip()))
    amplitudes5 = np.append(amplitudes5,float(split[5].strip()))
    
plt.figure(2)
plt.scatter(frequencies, amplitudes1/max(amplitudes1), color = "red", label = "simulation")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
f = open("SIG1704.txt","r")
frequencies1 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies1 = np.append(frequencies1,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude1 = np.sqrt(real**2 + imag**2)

f = open("SIG1734.txt","r")
frequencies12 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies12 = np.append(frequencies12,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude12 = np.sqrt(real**2 + imag**2)

plt.figure(1)
plt.plot(frequencies1, amplitude1,label='No Crack')
plt.plot(frequencies12, amplitude12,label='Crack')
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]",fontsize=12)
plt.ylabel("Amplitude",fontsize=12)
plt.title("Experiment Accelerometer 1")
plt.legend(loc='lower right')
plt.show() 

f = open("SIG1705.txt","r")
frequencies2 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies2 = np.append(frequencies2,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude2 = np.sqrt(real**2 + imag**2)

f = open("SIG1735.txt","r")
frequencies22 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies22 = np.append(frequencies22,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude22 = np.sqrt(real**2 + imag**2)

plt.figure(2)
plt.plot(frequencies2, amplitude2,label='No Crack')
plt.plot(frequencies22, amplitude22,label='Crack')
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]",fontsize=12)
plt.ylabel("Amplitude",fontsize=12)
plt.title("Experiment Accelerometer 2")
plt.legend(loc='lower right')
plt.show() 

f = open("SIG1706.txt","r")
frequencies3 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies3 = np.append(frequencies3,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude3 = np.sqrt(real**2 + imag**2)

f = open("SIG1736.txt","r")
frequencies32 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies32 = np.append(frequencies32,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude32 = np.sqrt(real**2 + imag**2)

plt.figure(2)
plt.plot(frequencies3, amplitude3,label='No Crack')
plt.plot(frequencies32, amplitude32,label='Crack')
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]",fontsize=12)
plt.ylabel("Amplitude",fontsize=12)
plt.title("Experiment Accelerometer 3")
plt.legend(loc='lower right')
plt.show() 

f = open("SIG1707.txt","r")
frequencies4 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies4 = np.append(frequencies4,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude4 = np.sqrt(real**2 + imag**2)

f = open("SIG1737.txt","r")
frequencies42 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies42 = np.append(frequencies42,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude42 = np.sqrt(real**2 + imag**2)

plt.figure(2)
plt.plot(frequencies4, amplitude4,label='No Crack')
plt.plot(frequencies42, amplitude42,label='Crack')
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]",fontsize=12)
plt.ylabel("Amplitude",fontsize=12)
plt.title("Experiment Accelerometer 4")
plt.legend(loc='lower right')
plt.show() 

f = open("SIG1708.txt","r")
frequencies5 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies5 = np.append(frequencies5,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude5 = np.sqrt(real**2 + imag**2)

f = open("SIG1738.txt","r")
frequencies52 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies52 = np.append(frequencies52,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude52 = np.sqrt(real**2 + imag**2)

plt.figure(2)
plt.plot(frequencies5, amplitude5,label='No Crack')
plt.plot(frequencies52, amplitude52,label='Crack')
plt.xlim(0,1000)
plt.yscale("log")
plt.xlabel("Frequency [Hz]",fontsize=12)
plt.ylabel("Amplitude",fontsize=12)
plt.title("Experiment Accelerometer 5")
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
f = open("SIG1704.txt","r")
frequencies1 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies1 = np.append(frequencies1,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude1 = np.sqrt(real**2 + imag**2)
plt.figure()
plt.scatter(real, imag)
plt.xlabel("Real")
plt.ylabel("Imag")
plt.title("Experiment Control Accelerometer 1")
plt.show() 

f = open("SIG1705.txt","r")
frequencies2 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies2 = np.append(frequencies2,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude2 = np.sqrt(real**2 + imag**2)
plt.figure()
plt.scatter(real, imag)
plt.xlabel("Real")
plt.ylabel("Imag")
plt.title("Experiment Control Accelerometer 2")
plt.show() 

f = open("SIG1706.txt","r")
frequencies3 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies3 = np.append(frequencies3,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude3 = np.sqrt(real**2 + imag**2)
plt.figure()
plt.scatter(real, imag)
plt.xlabel("Real")
plt.ylabel("Imag")
plt.title("Experiment Control Accelerometer 3")
plt.show() 

f = open("SIG1707.txt","r")
frequencies4 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies4 = np.append(frequencies4,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude4 = np.sqrt(real**2 + imag**2)
plt.figure()
plt.scatter(real, imag)
plt.xlabel("Real")
plt.ylabel("Imag")
plt.title("Experiment Control Accelerometer 4")
plt.show() 

f = open("SIG1708.txt","r")
frequencies5 = np.array([])
real = np.array([])
imag = np.array([])
for line in f:
    split = line.split(",")
    frequencies5 = np.append(frequencies5,float(split[0]))
    real = np.append(real,float(split[1]))
    imag = np.append(imag,float(split[2]))

f.close()    
amplitude5 = np.sqrt(real**2 + imag**2)
plt.figure()
plt.scatter(real, imag)
plt.xlabel("Real")
plt.ylabel("Imag")
plt.title("Experiment Control Accelerometer 5")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
f = open("SIG1704.txt","r")
frequencies1 = np.array([])
real1 = np.array([])
imag1 = np.array([])
for line in f:
    split = line.split(",")
    frequencies1 = np.append(frequencies1,float(split[0]))
    real1 = np.append(real1,float(split[1]))
    imag1 = np.append(imag1,float(split[2]))

f.close()    
amplitude1 = np.sqrt(real**2 + imag**2)

f = open("SIG1734.txt","r")
frequencies12 = np.array([])
real2 = np.array([])
imag2 = np.array([])
for line in f:
    split = line.split(",")
    frequencies12 = np.append(frequencies12,float(split[0]))
    real2 = np.append(real2,float(split[1]))
    imag2 = np.append(imag2,float(split[2]))

f.close()    
amplitude12 = np.sqrt(real**2 + imag**2)

plt.figure(1)
plt.plot(real1, imag2,label='No Crack',marker='o')
plt.plot(real2, imag2,label='Crack',marker='o')
plt.xlabel("Real",fontsize=12)
plt.ylabel("Imag",fontsize=12)
plt.title("Experiment Accelerometer 1")
plt.legend(loc='lower right')
plt.show() 

f = open("SIG1706.txt","r")
frequencies1 = np.array([])
real1 = np.array([])
imag1 = np.array([])
for line in f:
    split = line.split(",")
    frequencies1 = np.append(frequencies1,float(split[0]))
    real1 = np.append(real1,float(split[1]))
    imag1 = np.append(imag1,float(split[2]))

f.close()    
amplitude1 = np.sqrt(real**2 + imag**2)

f = open("SIG1736.txt","r")
frequencies12 = np.array([])
real2 = np.array([])
imag2 = np.array([])
for line in f:
    split = line.split(",")
    frequencies12 = np.append(frequencies12,float(split[0]))
    real2 = np.append(real2,float(split[1]))
    imag2 = np.append(imag2,float(split[2]))

f.close()    
amplitude12 = np.sqrt(real**2 + imag**2)

plt.figure(1)
plt.plot(real1, imag2,label='No Crack',marker='o')
plt.plot(real2, imag2,label='Crack',marker='o')
plt.xlabel("Real",fontsize=12)
plt.ylabel("Imag",fontsize=12)
plt.title("Experiment Accelerometer 3")
plt.legend(loc='lower right')
plt.show()
